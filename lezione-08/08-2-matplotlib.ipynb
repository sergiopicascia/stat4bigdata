# %% [markdown]
# # [Matplotlib](https://matplotlib.org)
#
# Matplotlib è una libreria utilizzata per creare visualizzazioni statiche, animate ed interagibili in Python.

# %%
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Matplotlib mostra i dati in una `Figure`, la quale a sua volta contiene uno o più `Axes`, ovvero un'area in cui è possibile specificare punti in termini di coordinate x e y. La funzione `pyplot.subplots` permette di creare facilmente questi due oggetti.

# %%
fig, ax = plt.subplots()
plt.show()

# %%
fig, ax = plt.subplots(2, 2)
plt.show()

# %% [markdown]
# `Axes.plot()` permette di disegnare un grafico con linee e punti, impostando le coordinate x e y.

# %%
fig, ax = plt.subplots()
ax.plot([1, 2, 3, 4], [1, 4, 2, 3])
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot([1, 2, 3, 4], [1, 4, 2, 3], marker='o')
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot([1, 2, 3, 4], [1, 4, 2, 3], marker='v')
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot([1, 2, 3, 4], [1, 4, 2, 3], marker='o', linestyle=':')
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot([1, 2, 3, 4], 
        [1, 4, 2, 3], 
        marker='o', 
        linestyle='-.',
        color='green',
        linewidth=5,
        markersize=10)
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot([1, 2, 3, 4], 
        [1, 4, 2, 3], 
        marker='o', 
        linestyle='-.',
        color='green',
        linewidth=5,
        markersize=10)
ax.plot([1, 2, 3, 4],
        [2, 3, 3, 4],
        marker='8',
        linestyle='--',
        color='orange'
)
plt.show()

# %%
import numpy as np

# %%
n = np.arange(0, 5, 0.2)

# %%
fig, ax = plt.subplots()
ax.plot(n, marker='x')
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(n)
ax.plot(n**2)
ax.plot(n**3)
plt.show()

# %%
a = np.arange(50)
b = a + 10 * np.random.randn(50)
c = np.random.randint(0, 50, 50)
s = np.abs(np.random.randn(50)) * 100

# %%
fig, ax = plt.subplots()
ax.scatter(x=a, y=b, c=c, s=s)
plt.show()

# %%
gruppi = ['gruppo_1', 'gruppo_2', 'gruppo_3']
valori = [1, 10, 100]

# %%
fig, ax = plt.subplots()
ax.bar(gruppi, height=valori)
plt.show()

# %%
fig, axs = plt.subplots(1, 3, figsize=(10, 5))

axs[0].bar(gruppi, valori)
axs[1].scatter(gruppi, valori)
axs[2].plot(gruppi, valori)

plt.show()
